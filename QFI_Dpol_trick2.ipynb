# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
# Define the device
dev = qml.device('default.mixed', wires=3)

# %%
x = np.array([np.pi])
Phi=2*np.arccos(np.sqrt((1-np.sin(x))/2))

# %%
def circuit(x,p,params):
    qml.RY(x,wires=0)
    qml.U3(params[0], params[1], params[2], wires=0)
    qml.U3(params[3], params[4], params[5], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[6], wires=0)
    qml.RY(params[7], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[8], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[9], params[10], params[11], wires=0)
    qml.U3(params[12], params[13], params[14], wires=1)

    qml.RZ(params[15], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[16], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[17], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[18], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[19], params[20], params[21], wires=0)
    qml.U3(params[22], params[23], params[24], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[25], wires=0)
    qml.RY(params[26], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[27], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[28], params[29], params[30], wires=0)
    qml.U3(params[31], params[32], params[33], wires=1)

    qml.RY(params[34], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[35], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RY(params[36], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[37], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[38], params[39], params[40], wires=0)
    qml.U3(params[41], params[42], params[43], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[44], wires=0)
    qml.RY(params[45], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[46], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[47], params[48], params[49], wires=0)
    qml.U3(params[50], params[51], params[52], wires=1)

    qml.RZ(params[53], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[54], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[55], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[56], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[57], params[58], params[59], wires=0)
    qml.U3(params[60], params[61], params[62], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[63], wires=0)
    qml.RY(params[64], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[65], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[66], params[67], params[68], wires=0)
    qml.U3(params[69], params[70], params[71], wires=1)
    qml.DepolarizingChannel(1-p,wires=0)
    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)



    return qml.density_matrix(wires=[0,1,2])

@qml.qnode(dev,diff_method="backprop")
def circuit1(x,p,params):
    qml.RY(Phi,wires=0)
    qml.U3(params[0], params[1], params[2], wires=0)
    qml.U3(params[3], params[4], params[5], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[6], wires=0)
    qml.RY(params[7], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[8], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[9], params[10], params[11], wires=0)
    qml.U3(params[12], params[13], params[14], wires=1)

    qml.RZ(params[15], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[16], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[17], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[18], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[19], params[20], params[21], wires=0)
    qml.U3(params[22], params[23], params[24], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[25], wires=0)
    qml.RY(params[26], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[27], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[28], params[29], params[30], wires=0)
    qml.U3(params[31], params[32], params[33], wires=1)

    qml.RY(params[34], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[35], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RY(params[36], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[37], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[38], params[39], params[40], wires=0)
    qml.U3(params[41], params[42], params[43], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[44], wires=0)
    qml.RY(params[45], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[46], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[47], params[48], params[49], wires=0)
    qml.U3(params[50], params[51], params[52], wires=1)

    qml.RZ(params[53], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[54], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[55], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[56], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[57], params[58], params[59], wires=0)
    qml.U3(params[60], params[61], params[62], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[63], wires=0)
    qml.RY(params[64], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[65], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[66], params[67], params[68], wires=0)
    qml.U3(params[69], params[70], params[71], wires=1)

    qml.DepolarizingChannel(1-p,wires=0)
    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)
    return qml.density_matrix(wires=[0,1,2])

@qml.qnode(dev,diff_method="backprop")
def circuit2(p,params):
    qml.U3(params[0], params[1], params[2], wires=0)
    qml.U3(params[3], params[4], params[5], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[6], wires=0)
    qml.RY(params[7], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[8], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[9], params[10], params[11], wires=0)
    qml.U3(params[12], params[13], params[14], wires=1)

    qml.RZ(params[15], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[16], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[17], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[18], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[19], params[20], params[21], wires=0)
    qml.U3(params[22], params[23], params[24], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[25], wires=0)
    qml.RY(params[26], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[27], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[28], params[29], params[30], wires=0)
    qml.U3(params[31], params[32], params[33], wires=1)

    qml.RY(params[34], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[35], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RY(params[36], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[37], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[38], params[39], params[40], wires=0)
    qml.U3(params[41], params[42], params[43], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[44], wires=0)
    qml.RY(params[45], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[46], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[47], params[48], params[49], wires=0)
    qml.U3(params[50], params[51], params[52], wires=1)

    qml.RZ(params[53], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[54], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[55], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[56], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[57], params[58], params[59], wires=0)
    qml.U3(params[60], params[61], params[62], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[63], wires=0)
    qml.RY(params[64], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[65], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[66], params[67], params[68], wires=0)
    qml.U3(params[69], params[70], params[71], wires=1)

    qml.DepolarizingChannel(1-p,wires=0)
    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)


    return qml.density_matrix(wires=[0,1,2])

@qml.qnode(dev,diff_method="backprop")
def circuit3(p,params):
    # qml.RY(Phi,wires=0)
    qml.RY(np.pi,wires=0)
    qml.U3(params[0], params[1], params[2], wires=0)
    qml.U3(params[3], params[4], params[5], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[6], wires=0)
    qml.RY(params[7], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[8], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[9], params[10], params[11], wires=0)
    qml.U3(params[12], params[13], params[14], wires=1)

    qml.RZ(params[15], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[16], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[17], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[18], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[19], params[20], params[21], wires=0)
    qml.U3(params[22], params[23], params[24], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[25], wires=0)
    qml.RY(params[26], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[27], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[28], params[29], params[30], wires=0)
    qml.U3(params[31], params[32], params[33], wires=1)

    qml.RY(params[34], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[35], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RY(params[36], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RY(params[37], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[38], params[39], params[40], wires=0)
    qml.U3(params[41], params[42], params[43], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[44], wires=0)
    qml.RY(params[45], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[46], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[47], params[48], params[49], wires=0)
    qml.U3(params[50], params[51], params[52], wires=1)

    qml.RZ(params[53], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[54], wires=2)
    qml.CNOT(wires=[0, 2])
    qml.RZ(params[55], wires=2)
    qml.CNOT(wires=[1, 2])
    qml.RZ(params[56], wires=2)
    qml.CNOT(wires=[0, 2])

    qml.U3(params[57], params[58], params[59], wires=0)
    qml.U3(params[60], params[61], params[62], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.RZ(params[63], wires=0)
    qml.RY(params[64], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(params[65], wires=1)
    qml.CNOT(wires=[1, 0])
    qml.U3(params[66], params[67], params[68], wires=0)
    qml.U3(params[69], params[70], params[71], wires=1)

    qml.DepolarizingChannel(1-p,wires=0)
    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)



    return qml.density_matrix(wires=[0,1,2])

# %%
def cost(x, p, params):
    circuit_output = circuit(x,p,params)
    eig_values, eig_vectors = np.linalg.eigh(circuit_output)
    
    complex_jacobian_matrix = circuit1(x,p,params)-1/2*circuit2(p,params)-1/2*circuit3(p,params)
    
    L_theta = np.zeros_like(circuit_output)
    
    for n in range(len(eig_values)):
        for m in range(len(eig_values)):
            if not np.isclose(eig_values[n] + eig_values[m], 0):
                matrix_element = np.dot(np.conj(eig_vectors[:, m]).T,np.dot(complex_jacobian_matrix, eig_vectors[:, n]))
                L_theta =L_theta + (2 * matrix_element / (eig_values[n] + eig_values[m])) * np.outer(eig_vectors[:, m], np.conj(eig_vectors[:, n]))
    
    L_theta_squared = np.dot(L_theta, L_theta)
    QFI = np.trace(np.dot(L_theta_squared, circuit_output))
    
    return -np.real(QFI)

# %%
opt = qml.SPSAOptimizer(maxiter=1)

p_values = np.linspace(0.00001, 0.9999, 21)
QFI_values = []

for p in p_values:
    maxQFI = 0  
    seed_val = 10

    # Optimization loop for different seeds
    for seed in range(seed_val):
        np.random.seed(seed)
        params = np.random.uniform(-np.pi,np.pi,63)  
        costs = []

        for i in range(1):
            params, current_cost = opt.step_and_cost(lambda params: cost(x, p, params), params)
            costs.append(current_cost)

            # if (i + 1) % 10 == 0:
            #     print(f"Step {i + 1}: Cost = {current_cost}")

        QFI_value = -costs[-1]  
        if QFI_value > maxQFI:
            maxQFI = QFI_value  

    QFI_values.append(maxQFI)
