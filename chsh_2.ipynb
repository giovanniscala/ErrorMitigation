# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt

# %%
proj = np.array([[1, 0], [0, 0]])

# Selecting the device
dev = qml.device("default.mixed", wires=4)

# Function to create the CHSH observables
def create_observable(theta, phi):
    return np.array([[np.cos(theta), np.exp(-1j * phi) * np.sin(theta)],
                     [np.exp(1j * phi) * np.sin(theta), -np.cos(theta)]])

# %%
def bell_pair(params,p):
    qml.Hadamard(0)
    qml.CNOT(wires=[0,1])
    
    qml.U3(params[0],params[1],params[2],wires=1)
    qml.U3(params[3],params[4],params[5],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[6],wires=1)
    qml.RY(params[7],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[8],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[9],params[10],params[11],wires=1)
    qml.U3(params[12],params[13],params[14],wires=2)

    qml.RZ(params[15],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[16],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[17],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[18],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[19],params[20],params[21],wires=1)
    qml.U3(params[22],params[23],params[24],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[25],wires=1)
    qml.RY(params[26],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[27],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[28],params[29],params[30],wires=1)
    qml.U3(params[31],params[32],params[33],wires=2)

    qml.RY(params[34],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[35],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[36],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[37],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[38],params[39],params[40],wires=1)
    qml.U3(params[41],params[42],params[43],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[44],wires=1)
    qml.RY(params[45],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[46],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[47],params[48],params[49],wires=1)
    qml.U3(params[50],params[51],params[52],wires=2)

    qml.RZ(params[53],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[54],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[55],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[56],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[57],params[58],params[59],wires=1)
    qml.U3(params[60],params[61],params[62],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[63],wires=1)
    qml.RY(params[64],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[65],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[66],params[67],params[68],wires=1)
    qml.U3(params[69],params[70],params[71],wires=2)

    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)
    qml.DepolarizingChannel(1-p,wires=3)

    qml.adjoint(qml.U3(params[69],params[70],params[71],wires=2))
    qml.adjoint(qml.U3(params[66],params[67],params[68],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[65],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[64],wires=2))
    qml.adjoint(qml.RZ(params[63],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[60],params[61],params[62],wires=2))
    qml.adjoint(qml.U3(params[57],params[58],params[59],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[56],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[55],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[54],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[53],wires=[3]))

    qml.adjoint(qml.U3(params[50],params[51],params[52],wires=2))
    qml.adjoint(qml.U3(params[47],params[48],params[49],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[46],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[45],wires=2))
    qml.adjoint(qml.RZ(params[44],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[41],params[42],params[43],wires=2))
    qml.adjoint(qml.U3(params[38],params[39],params[40],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[37],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[36],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[35],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[34],wires=[3]))

    qml.adjoint(qml.U3(params[31],params[32],params[33],wires=2))
    qml.adjoint(qml.U3(params[28],params[29],params[30],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[27],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[26],wires=2))
    qml.adjoint(qml.RZ(params[25],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[22],params[23],params[24],wires=2))
    qml.adjoint(qml.U3(params[19],params[20],params[21],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[18],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[17],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[16],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[15],wires=[3]))

    qml.adjoint(qml.U3(params[12],params[13],params[14],wires=2))
    qml.adjoint(qml.U3(params[9],params[10],params[11],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[8],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[7],wires=2))
    qml.adjoint(qml.RZ(params[6],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[3],params[4],params[5],wires=2))
    qml.adjoint(qml.U3(params[0],params[1],params[2],wires=1))
    
    qml.QubitUnitary(proj,wires=2)
    qml.QubitUnitary(proj,wires=3)

# #     # Return the density matrix for the first two qubits

# %%
@qml.qnode(dev)
def bell_pair1(params,p):
    qml.Hadamard(0)
    qml.CNOT(wires=[0,1])
    
    qml.U3(params[0],params[1],params[2],wires=1)
    qml.U3(params[3],params[4],params[5],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[6],wires=1)
    qml.RY(params[7],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[8],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[9],params[10],params[11],wires=1)
    qml.U3(params[12],params[13],params[14],wires=2)

    qml.RZ(params[15],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[16],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[17],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[18],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[19],params[20],params[21],wires=1)
    qml.U3(params[22],params[23],params[24],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[25],wires=1)
    qml.RY(params[26],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[27],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[28],params[29],params[30],wires=1)
    qml.U3(params[31],params[32],params[33],wires=2)

    qml.RY(params[34],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[35],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[36],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[37],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[38],params[39],params[40],wires=1)
    qml.U3(params[41],params[42],params[43],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[44],wires=1)
    qml.RY(params[45],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[46],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[47],params[48],params[49],wires=1)
    qml.U3(params[50],params[51],params[52],wires=2)

    qml.RZ(params[53],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[54],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[55],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[56],wires=[3])
    qml.CNOT(wires=[1,3])


    qml.U3(params[57],params[58],params[59],wires=1)
    qml.U3(params[60],params[61],params[62],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[63],wires=1)
    qml.RY(params[64],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[65],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[66],params[67],params[68],wires=1)
    qml.U3(params[69],params[70],params[71],wires=2)

    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)
    qml.DepolarizingChannel(1-p,wires=3)

    qml.adjoint(qml.U3(params[69],params[70],params[71],wires=2))
    qml.adjoint(qml.U3(params[66],params[67],params[68],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[65],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[64],wires=2))
    qml.adjoint(qml.RZ(params[63],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[60],params[61],params[62],wires=2))
    qml.adjoint(qml.U3(params[57],params[58],params[59],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[56],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[55],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[54],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[53],wires=[3]))

    qml.adjoint(qml.U3(params[50],params[51],params[52],wires=2))
    qml.adjoint(qml.U3(params[47],params[48],params[49],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[46],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[45],wires=2))
    qml.adjoint(qml.RZ(params[44],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[41],params[42],params[43],wires=2))
    qml.adjoint(qml.U3(params[38],params[39],params[40],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[37],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[36],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[35],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[34],wires=[3]))

    qml.adjoint(qml.U3(params[31],params[32],params[33],wires=2))
    qml.adjoint(qml.U3(params[28],params[29],params[30],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[27],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[26],wires=2))
    qml.adjoint(qml.RZ(params[25],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[22],params[23],params[24],wires=2))
    qml.adjoint(qml.U3(params[19],params[20],params[21],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[18],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[17],wires=[3]))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[16],wires=[3]))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[15],wires=[3]))

    qml.adjoint(qml.U3(params[12],params[13],params[14],wires=2))
    qml.adjoint(qml.U3(params[9],params[10],params[11],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[8],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[7],wires=2))
    qml.adjoint(qml.RZ(params[6],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[3],params[4],params[5],wires=2))
    qml.adjoint(qml.U3(params[0],params[1],params[2],wires=1))
    

    qml.QubitUnitary(proj,wires=2)
    qml.QubitUnitary(proj,wires=3)

    return qml.density_matrix(wires=[0, 1])

# %%
def measure_AB(dev, bell_pair, A, B):
    @qml.qnode(dev)
    def circuit(params,p):
        bell_pair(params[:72],p) 
        return qml.expval(qml.Hermitian(A, wires=0) @ qml.Hermitian(B, wires=1))
    return circuit

# Cost function
def cost(params,p):
    # Creating observables with new parameters
    A1 = create_observable(0, 0)
    A2 = create_observable(np.pi/2, 0)
    B1 = create_observable(np.pi/4, 0)
    B2 = create_observable(np.pi/4, np.pi)
    trace=np.trace(bell_pair1(params,p))

    trace=np.trace(bell_pair1(params,p))

    expvals = [measure_AB(dev, bell_pair, A1, B1)(params,p)/trace,
               measure_AB(dev, bell_pair, A1, B2)(params,p)/trace,
               measure_AB(dev, bell_pair, A2, B1)(params,p)/trace,
               measure_AB(dev, bell_pair, A2, B2)(params,p)/trace]
    return -np.real((np.sum(expvals[:3]) - expvals[3]))

# %%
p_val = np.linspace(0.25,1,0.5)
CHSH = []
par = []
Prob_SUCESS = []
adam_opt = qml.AdamOptimizer(0.1)
adam_steps = 1000 

for p in p_val:
    params = np.array(np.random.uniform(-np.pi, np.pi,72), requires_grad=True)


    for i in range(adam_steps):
        params, ccost = adam_opt.step_and_cost(lambda v: cost(v, p), params)
        print(f"Step {i + 1}/{adam_steps}, Cost: {ccost}")

    PS = np.trace(bell_pair1(params, p))

    CHSH.append(ccost)
    par.append(params)
    Prob_SUCESS.append(PS)

print("CHSH:", CHSH)
print("Params:", par)
print("Prob_SUCESS:", Prob_SUCESS)
# Out:
# Adam Step 1/100, Cost: -0.6764593174548227
# Adam Step 2/100, Cost: -0.6872506665698639
# Adam Step 3/100, Cost: -0.7692130181386683
# Adam Step 4/100, Cost: -0.8185047672124159
# Adam Step 5/100, Cost: -0.8185384445483912
# Adam Step 6/100, Cost: -0.8829733146928977
# Adam Step 7/100, Cost: -0.9220682401145037
# Adam Step 8/100, Cost: -0.914070206665596
# Adam Step 9/100, Cost: -0.9274953588051325
# Adam Step 10/100, Cost: -0.9555139023190609
# Adam Step 11/100, Cost: -0.9920622168713054
# Adam Step 12/100, Cost: -1.0015964886674942
# Adam Step 13/100, Cost: -0.9867414122763817
# Adam Step 14/100, Cost: -0.9944533709500663
# Adam Step 15/100, Cost: -1.012146172481837
# Adam Step 16/100, Cost: -1.016898448848572
# Adam Step 17/100, Cost: -1.0150179006342388
# Adam Step 18/100, Cost: -1.0108381571682203
# Adam Step 19/100, Cost: -1.0093459882968023
# Adam Step 20/100, Cost: -1.0188207869834636
# Adam Step 21/100, Cost: -1.0286783511048208
# Adam Step 22/100, Cost: -1.0270639348919905
# Adam Step 23/100, Cost: -1.0227204579388376
# Adam Step 24/100, Cost: -1.0249449823884595
# Adam Step 25/100, Cost: -1.031393321193676
# Adam Step 26/100, Cost: -1.0356737751429692
# Adam Step 27/100, Cost: -1.0354717795378843
# Adam Step 28/100, Cost: -1.032954196337272
# Adam Step 29/100, Cost: -1.0308520045421155
# Adam Step 30/100, Cost: -1.032097716896914
# Adam Step 31/100, Cost: -1.0360399208868922
# Adam Step 32/100, Cost: -1.0381824194597704
# Adam Step 33/100, Cost: -1.0381106316411077
# Adam Step 34/100, Cost: -1.0384155136147435
# Adam Step 35/100, Cost: -1.0383935131406683
# Adam Step 36/100, Cost: -1.038341181660875
# Adam Step 37/100, Cost: -1.0391775857632632
# Adam Step 38/100, Cost: -1.0388868328445777
# Adam Step 39/100, Cost: -1.0384211474138965
# Adam Step 40/100, Cost: -1.0398103942496426
# Adam Step 41/100, Cost: -1.0410814273972808
# Adam Step 42/100, Cost: -1.041255246411501
# Adam Step 43/100, Cost: -1.0409215603544857
# Adam Step 44/100, Cost: -1.0405395922805054
# Adam Step 45/100, Cost: -1.0410683002094927
# Adam Step 46/100, Cost: -1.0416955878713194
# Adam Step 47/100, Cost: -1.04155221652586
# Adam Step 48/100, Cost: -1.0413088917153033
# Adam Step 49/100, Cost: -1.0413869156029303
# Adam Step 50/100, Cost: -1.041754697354942
# Adam Step 51/100, Cost: -1.0422237865979902
# Adam Step 52/100, Cost: -1.0424228938506976
# Adam Step 53/100, Cost: -1.0422344679626963
# Adam Step 54/100, Cost: -1.042029208654093
# Adam Step 55/100, Cost: -1.0422058645121735
# Adam Step 56/100, Cost: -1.042490866845372
# Adam Step 57/100, Cost: -1.0425492467132575
# Adam Step 58/100, Cost: -1.0424624581685602
# Adam Step 59/100, Cost: -1.0424150581578298
# Adam Step 60/100, Cost: -1.0425622391844718
# Adam Step 61/100, Cost: -1.0426416737211608
# Adam Step 62/100, Cost: -1.0426035298743552
# Adam Step 63/100, Cost: -1.0426318167685114
# Adam Step 64/100, Cost: -1.0426375407876098
# Adam Step 65/100, Cost: -1.0427424853807246
# Adam Step 66/100, Cost: -1.0428100647627045
# Adam Step 67/100, Cost: -1.042762123851595
# Adam Step 68/100, Cost: -1.0427643737033407
# Adam Step 69/100, Cost: -1.0427866696063532
# Adam Step 70/100, Cost: -1.0428460460227336
# Adam Step 71/100, Cost: -1.0428113450935217
# Adam Step 72/100, Cost: -1.042794376499571
# Adam Step 73/100, Cost: -1.0428616041539784
# Adam Step 74/100, Cost: -1.0428845704370677
# Adam Step 75/100, Cost: -1.042880605608888
# Adam Step 76/100, Cost: -1.0428601142605558
# Adam Step 77/100, Cost: -1.042882834411075
# Adam Step 78/100, Cost: -1.0429117621260018
# Adam Step 79/100, Cost: -1.0429108274364018
# Adam Step 80/100, Cost: -1.042895059029582
# Adam Step 81/100, Cost: -1.0429028511015574
# Adam Step 82/100, Cost: -1.0429323463757305
# Adam Step 83/100, Cost: -1.0429311262844598
# Adam Step 84/100, Cost: -1.0429109074653073
# Adam Step 85/100, Cost: -1.0429183450680017
# Adam Step 86/100, Cost: -1.0429352212766505
# Adam Step 87/100, Cost: -1.0429348671188305
# Adam Step 88/100, Cost: -1.042935749441425
# Adam Step 89/100, Cost: -1.0429412825528368
# Adam Step 90/100, Cost: -1.0429487634640513
# Adam Step 91/100, Cost: -1.042941020852094
# Adam Step 92/100, Cost: -1.0429394219631778
# Adam Step 93/100, Cost: -1.0429418308793938
# Adam Step 94/100, Cost: -1.0429511878951787
# Adam Step 95/100, Cost: -1.0429474538489214
# Adam Step 96/100, Cost: -1.0429493333172433
# Adam Step 97/100, Cost: -1.0429543560181798
# Adam Step 98/100, Cost: -1.0429548926325785
# Adam Step 99/100, Cost: -1.0429498859677315
# Adam Step 100/100, Cost: -1.0429516128553626
# CHSH: [-1.0429516128553626]
# Params: [tensor([ 2.39793986e+00,  1.46344007e+00, -7.60898934e-01,
#         -7.25426899e-01,  2.40926650e+00, -2.99973231e+00,
#          7.52177584e-01, -3.04670501e+00,  1.89673512e+00,
#          1.68986861e+00, -1.46493009e+00,  2.55333389e+00,
#         -8.25882659e-01,  5.40148371e-01, -1.46970519e+00,
#          2.00326092e+00, -2.40031621e+00,  5.34874442e-01,
#          1.32611760e+00,  5.44134322e-02,  3.06897095e+00,
#          2.26388953e+00, -1.87935613e+00,  1.29213804e+00,
#          3.20171639e-01,  1.72399986e+00,  1.96141248e+00,
#         -4.80185530e-01, -2.17956762e+00,  5.28048868e-01,
#          2.29396229e+00, -1.95293877e-02, -2.47584521e+00,
#         -3.07465793e+00, -1.57068522e+00,  1.30641204e-03,
#          1.57076223e+00, -4.27344942e-04,  3.13642897e+00,
#          2.92948634e+00,  2.98555027e+00, -3.51424891e+00,
#         -3.13641979e+00, -1.70638311e+00, -2.15844974e+00,
#         -1.31920118e+00, -4.63008037e-01, -2.15941429e+00,
#         -8.33453967e-01, -2.20196668e+00,  6.78296577e-02,
#          2.24040048e+00,  1.87189025e+00, -1.91487188e+00,
#          2.02794643e+00, -2.50890772e+00,  8.68881495e-01,
#          1.40903974e+00,  8.82941667e-01, -3.07051040e+00,
#          3.01764658e+00, -1.92167062e+00, -9.69159661e-01,
#          1.68625018e-01, -1.71560824e+00,  1.29244489e+00,
#          2.11339053e+00, -9.34743465e-01,  1.89774941e+00,
#         -1.71171084e+00,  1.87351247e+00, -2.68503480e+00], requires_grad=True)]
# Prob_SUCESS: [(0.3033333603476228-1.0972125985553305e-16j)]
