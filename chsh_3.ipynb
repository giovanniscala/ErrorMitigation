# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt

# %%
proj = np.array([[1, 0], [0, 0]])

# Selecting the device
dev = qml.device("default.mixed", wires=5)

# Function to create the CHSH observables
def create_observable(theta, phi):
    return np.array([[np.cos(theta), np.exp(-1j * phi) * np.sin(theta)],
                     [np.exp(1j * phi) * np.sin(theta), -np.cos(theta)]])

# %%
def bell_pair(params,p):
    qml.Hadamard(0)
    qml.CNOT(wires=[0,1])
    qml.U3(params[0],params[1],params[2],wires=1)
    qml.U3(params[3],params[4],params[5],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[6],wires=1)
    qml.RY(params[7],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[8],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[9],params[10],params[11],wires=1)
    qml.U3(params[12],params[13],params[14],wires=2)

    qml.RZ(params[15],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[16],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[17],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[18],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[19],params[20],params[21],wires=1)
    qml.U3(params[22],params[23],params[24],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[25],wires=1)
    qml.RY(params[26],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[27],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[28],params[29],params[30],wires=1)
    qml.U3(params[31],params[32],params[33],wires=2)

    qml.RY(params[34],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[35],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[36],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[37],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[38],params[39],params[40],wires=1)
    qml.U3(params[41],params[42],params[43],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[44],wires=1)
    qml.RY(params[45],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[46],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[47],params[48],params[49],wires=1)
    qml.U3(params[50],params[51],params[52],wires=2)

    qml.RZ(params[53],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[54],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[55],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[56],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[57],params[58],params[59],wires=1)
    qml.U3(params[60],params[61],params[62],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[63],wires=1)
    qml.RY(params[64],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[65],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[66],params[67],params[68],wires=1)
    qml.U3(params[69],params[70],params[71],wires=2)






    qml.RZ(params[72],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[73],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[74],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[75],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RZ(params[76],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[77],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[78],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[79],wires=[4])
    qml.CNOT(wires=[1,4])





    qml.U3(params[80],params[81],params[82],wires=1)
    qml.U3(params[83],params[84],params[85],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[86],wires=1)
    qml.RY(params[87],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[88],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[89],params[90],params[91],wires=1)
    qml.U3(params[92],params[93],params[94],wires=2)

    qml.RZ(params[95],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[96],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[97],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[98],wires=[3])
    qml.CNOT(wires=[1,3])
#######
    qml.U3(params[99],params[100],params[101],wires=1)
    qml.U3(params[102],params[103],params[104],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[105],wires=1)
    qml.RY(params[106],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[107],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[108],params[109],params[110],wires=1)
    qml.U3(params[111],params[112],params[113],wires=2)

    qml.RY(params[114],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[115],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[116],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[117],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[118],params[119],params[120],wires=1)
    qml.U3(params[121],params[122],params[123],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[124],wires=1)
    qml.RY(params[125],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[126],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[127],params[128],params[129],wires=1)
    qml.U3(params[130],params[131],params[132],wires=2)

    qml.RZ(params[133],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[134],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[135],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[136],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[137],params[138],params[139],wires=1)
    qml.U3(params[140],params[141],params[142],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[143],wires=1)
    qml.RY(params[144],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[145],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[146],params[147],params[148],wires=1)
    qml.U3(params[149],params[150],params[151],wires=2)





    qml.RY(params[152],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[153],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RY(params[154],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[155],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RY(params[156],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[157],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RY(params[158],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[159],wires=[4])
    qml.CNOT(wires=[1,4])




    qml.U3(params[160],params[161],params[162],wires=1)
    qml.U3(params[163],params[164],params[165],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[166],wires=1)
    qml.RY(params[167],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[168],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[169],params[170],params[171],wires=1)
    qml.U3(params[172],params[173],params[174],wires=2)

    qml.RZ(params[175],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[176],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[177],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[178],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[179],params[180],params[181],wires=1)
    qml.U3(params[182],params[183],params[184],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[185],wires=1)
    qml.RY(params[186],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[187],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[188],params[189],params[190],wires=1)
    qml.U3(params[191],params[192],params[193],wires=2)

    qml.RY(params[194],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[195],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[196],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[197],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[198],params[199],params[200],wires=1)
    qml.U3(params[201],params[202],params[203],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[204],wires=1)
    qml.RY(params[205],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[206],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[207],params[208],params[209],wires=1)
    qml.U3(params[210],params[211],params[212],wires=2)

    qml.RZ(params[213],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[214],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[215],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[216],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[217],params[218],params[219],wires=1)
    qml.U3(params[220],params[221],params[222],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[223],wires=1)
    qml.RY(params[224],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[225],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[226],params[227],params[228],wires=1)
    qml.U3(params[229],params[230],params[231],wires=2)




    qml.RZ(params[232],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[233],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[234],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[235],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RZ(params[236],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[237],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[238],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[239],wires=[4])
    qml.CNOT(wires=[1,4])




    qml.U3(params[240],params[241],params[242],wires=1)
    qml.U3(params[243],params[244],params[245],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[246],wires=1)
    qml.RY(params[247],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[248],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[249],params[250],params[251],wires=1)
    qml.U3(params[252],params[253],params[254],wires=2)

    qml.RZ(params[255],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[256],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[257],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[258],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[259],params[260],params[261],wires=1)
    qml.U3(params[262],params[263],params[264],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[265],wires=1)
    qml.RY(params[266],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[267],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[268],params[269],params[270],wires=1)
    qml.U3(params[271],params[272],params[273],wires=2)

    qml.RY(params[274],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[275],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[276],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[277],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[278],params[279],params[280],wires=1)
    qml.U3(params[281],params[282],params[283],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[284],wires=1)
    qml.RY(params[285],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[286],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[287],params[288],params[289],wires=1)
    qml.U3(params[290],params[291],params[292],wires=2)

    qml.RZ(params[293],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[294],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[295],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[296],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[297],params[298],params[299],wires=1)
    qml.U3(params[300],params[301],params[302],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[303],wires=1)
    qml.RY(params[304],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[305],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[306],params[307],params[308],wires=1)
    qml.U3(params[309],params[310],params[311],wires=2)





    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)
    qml.DepolarizingChannel(1-p,wires=3)
    qml.DepolarizingChannel(1-p,wires=4)



    qml.adjoint(qml.U3(params[309],params[310],params[311],wires=2))
    qml.adjoint(qml.U3(params[306],params[307],params[308],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[305],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[304],wires=2))
    qml.adjoint(qml.RZ(params[303],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[300],params[301],params[302],wires=2))
    qml.adjoint(qml.U3(params[297],params[298],params[299],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[296], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[295], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[294], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[293], wires=3))

    qml.adjoint(qml.U3(params[290],params[291],params[292],wires=2))
    qml.adjoint(qml.U3(params[287],params[288],params[289],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[286],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[285],wires=2))
    qml.adjoint(qml.RZ(params[284],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[281],params[282],params[283],wires=2))
    qml.adjoint(qml.U3(params[278],params[279],params[280],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[277], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[276], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[275], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[274], wires=3))

    qml.adjoint(qml.U3(params[271],params[272],params[273],wires=2))
    qml.adjoint(qml.U3(params[268],params[269],params[270],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[267],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[266],wires=2))
    qml.adjoint(qml.RZ(params[265],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[262],params[263],params[264],wires=2))
    qml.adjoint(qml.U3(params[259],params[260],params[261],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[258], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[257], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[256], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[255], wires=3))

    qml.adjoint(qml.U3(params[252],params[253],params[254],wires=2))
    qml.adjoint(qml.U3(params[249],params[250],params[251],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[248],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[247],wires=2))
    qml.adjoint(qml.RZ(params[246],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[243],params[244],params[245],wires=2))
    qml.adjoint(qml.U3(params[240],params[241],params[242],wires=1))



    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[239], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[238], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[237], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[236], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[235], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[234], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[233], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[232], wires=4))



    qml.adjoint(qml.U3(params[229],params[230],params[231],wires=2))
    qml.adjoint(qml.U3(params[226],params[227],params[228],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[225],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[224],wires=2))
    qml.adjoint(qml.RZ(params[223],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[220],params[221],params[222],wires=2))
    qml.adjoint(qml.U3(params[217],params[218],params[219],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[216], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[215], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[214], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[213], wires=3))

    qml.adjoint(qml.U3(params[210],params[211],params[212],wires=2))
    qml.adjoint(qml.U3(params[207],params[208],params[209],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[206],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[205],wires=2))
    qml.adjoint(qml.RZ(params[204],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[201],params[202],params[203],wires=2))
    qml.adjoint(qml.U3(params[198],params[199],params[200],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[197], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[196], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[195], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[194], wires=3))

    qml.adjoint(qml.U3(params[191],params[192],params[193],wires=2))
    qml.adjoint(qml.U3(params[188],params[189],params[190],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[187],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[186],wires=2))
    qml.adjoint(qml.RZ(params[185],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[182],params[183],params[184],wires=2))
    qml.adjoint(qml.U3(params[179],params[180],params[181],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[178], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[177], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[176], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[175], wires=3))

    qml.adjoint(qml.U3(params[172],params[173],params[174],wires=2))
    qml.adjoint(qml.U3(params[169],params[170],params[171],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[168],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[167],wires=2))
    qml.adjoint(qml.RZ(params[166],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[163],params[164],params[165],wires=2))
    qml.adjoint(qml.U3(params[160],params[161],params[162],wires=1))


    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RY(params[159], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[158], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RY(params[157], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[156], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RY(params[155], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[154], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RY(params[153], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[152], wires=4))



    qml.adjoint(qml.U3(params[149],params[150],params[151],wires=2))
    qml.adjoint(qml.U3(params[146],params[147],params[148],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[145],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[144],wires=2))
    qml.adjoint(qml.RZ(params[143],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[140],params[141],params[142],wires=2))
    qml.adjoint(qml.U3(params[137],params[138],params[139],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[136], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[135], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[134], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[133], wires=3))

    qml.adjoint(qml.U3(params[130],params[131],params[132],wires=2))
    qml.adjoint(qml.U3(params[127],params[128],params[129],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[126],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[125],wires=2))
    qml.adjoint(qml.RZ(params[124],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[121],params[122],params[123],wires=2))
    qml.adjoint(qml.U3(params[118],params[119],params[120],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[117], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[116], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[115], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[114], wires=3))

    qml.adjoint(qml.U3(params[111],params[112],params[113],wires=2))
    qml.adjoint(qml.U3(params[108],params[109],params[110],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[107],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[106],wires=2))
    qml.adjoint(qml.RZ(params[105],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[102],params[103],params[104],wires=2))
    qml.adjoint(qml.U3(params[99],params[100],params[101],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[98], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[97], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[96], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[95], wires=3))

    qml.adjoint(qml.U3(params[92],params[93],params[94],wires=2))
    qml.adjoint(qml.U3(params[89],params[90],params[91],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[88],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[87],wires=2))
    qml.adjoint(qml.RZ(params[86],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[83],params[84],params[85],wires=2))
    qml.adjoint(qml.U3(params[80],params[81],params[82],wires=1))



    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[79], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[78], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[77], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[76], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[75], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[74], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[73], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[72], wires=4))



    qml.adjoint(qml.U3(params[69],params[70],params[71],wires=2))
    qml.adjoint(qml.U3(params[66],params[67],params[68],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[65],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[64],wires=2))
    qml.adjoint(qml.RZ(params[63],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[60],params[61],params[62],wires=2))
    qml.adjoint(qml.U3(params[57],params[58],params[59],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[56], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[55], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[54], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[53], wires=3))

    qml.adjoint(qml.U3(params[50],params[51],params[52],wires=2))
    qml.adjoint(qml.U3(params[47],params[48],params[49],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[46],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[45],wires=2))
    qml.adjoint(qml.RZ(params[44],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[41],params[42],params[43],wires=2))
    qml.adjoint(qml.U3(params[38],params[39],params[40],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[37], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[36], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[35], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[34], wires=3))

    qml.adjoint(qml.U3(params[31],params[32],params[33],wires=2))
    qml.adjoint(qml.U3(params[28],params[29],params[30],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[27],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[26],wires=2))
    qml.adjoint(qml.RZ(params[25],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[22],params[23],params[24],wires=2))
    qml.adjoint(qml.U3(params[19],params[20],params[21],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[18], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[17], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[16], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[15], wires=3))

    qml.adjoint(qml.U3(params[12],params[13],params[14],wires=2))
    qml.adjoint(qml.U3(params[9],params[10],params[11],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[8],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[7],wires=2))
    qml.adjoint(qml.RZ(params[6],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[3],params[4],params[5],wires=2))
    qml.adjoint(qml.U3(params[0],params[1],params[2],wires=1))


    qml.QubitUnitary(proj, wires=2)
    qml.QubitUnitary(proj, wires=3)
    qml.QubitUnitary(proj, wires=4)

# %%
@qml.qnode(dev)
def bell_pair1(params,p):
    qml.Hadamard(0)
    qml.CNOT(wires=[0,1])
    qml.U3(params[0],params[1],params[2],wires=1)
    qml.U3(params[3],params[4],params[5],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[6],wires=1)
    qml.RY(params[7],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[8],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[9],params[10],params[11],wires=1)
    qml.U3(params[12],params[13],params[14],wires=2)

    qml.RZ(params[15],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[16],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[17],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[18],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[19],params[20],params[21],wires=1)
    qml.U3(params[22],params[23],params[24],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[25],wires=1)
    qml.RY(params[26],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[27],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[28],params[29],params[30],wires=1)
    qml.U3(params[31],params[32],params[33],wires=2)

    qml.RY(params[34],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[35],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[36],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[37],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[38],params[39],params[40],wires=1)
    qml.U3(params[41],params[42],params[43],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[44],wires=1)
    qml.RY(params[45],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[46],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[47],params[48],params[49],wires=1)
    qml.U3(params[50],params[51],params[52],wires=2)

    qml.RZ(params[53],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[54],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[55],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[56],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[57],params[58],params[59],wires=1)
    qml.U3(params[60],params[61],params[62],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[63],wires=1)
    qml.RY(params[64],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[65],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[66],params[67],params[68],wires=1)
    qml.U3(params[69],params[70],params[71],wires=2)






    qml.RZ(params[72],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[73],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[74],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[75],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RZ(params[76],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[77],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[78],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[79],wires=[4])
    qml.CNOT(wires=[1,4])





    qml.U3(params[80],params[81],params[82],wires=1)
    qml.U3(params[83],params[84],params[85],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[86],wires=1)
    qml.RY(params[87],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[88],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[89],params[90],params[91],wires=1)
    qml.U3(params[92],params[93],params[94],wires=2)

    qml.RZ(params[95],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[96],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[97],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[98],wires=[3])
    qml.CNOT(wires=[1,3])
#######
    qml.U3(params[99],params[100],params[101],wires=1)
    qml.U3(params[102],params[103],params[104],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[105],wires=1)
    qml.RY(params[106],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[107],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[108],params[109],params[110],wires=1)
    qml.U3(params[111],params[112],params[113],wires=2)

    qml.RY(params[114],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[115],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[116],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[117],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[118],params[119],params[120],wires=1)
    qml.U3(params[121],params[122],params[123],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[124],wires=1)
    qml.RY(params[125],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[126],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[127],params[128],params[129],wires=1)
    qml.U3(params[130],params[131],params[132],wires=2)

    qml.RZ(params[133],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[134],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[135],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[136],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[137],params[138],params[139],wires=1)
    qml.U3(params[140],params[141],params[142],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[143],wires=1)
    qml.RY(params[144],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[145],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[146],params[147],params[148],wires=1)
    qml.U3(params[149],params[150],params[151],wires=2)





    qml.RY(params[152],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[153],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RY(params[154],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[155],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RY(params[156],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[157],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RY(params[158],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RY(params[159],wires=[4])
    qml.CNOT(wires=[1,4])




    qml.U3(params[160],params[161],params[162],wires=1)
    qml.U3(params[163],params[164],params[165],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[166],wires=1)
    qml.RY(params[167],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[168],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[169],params[170],params[171],wires=1)
    qml.U3(params[172],params[173],params[174],wires=2)

    qml.RZ(params[175],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[176],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[177],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[178],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[179],params[180],params[181],wires=1)
    qml.U3(params[182],params[183],params[184],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[185],wires=1)
    qml.RY(params[186],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[187],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[188],params[189],params[190],wires=1)
    qml.U3(params[191],params[192],params[193],wires=2)

    qml.RY(params[194],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[195],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[196],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[197],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[198],params[199],params[200],wires=1)
    qml.U3(params[201],params[202],params[203],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[204],wires=1)
    qml.RY(params[205],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[206],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[207],params[208],params[209],wires=1)
    qml.U3(params[210],params[211],params[212],wires=2)

    qml.RZ(params[213],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[214],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[215],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[216],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[217],params[218],params[219],wires=1)
    qml.U3(params[220],params[221],params[222],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[223],wires=1)
    qml.RY(params[224],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[225],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[226],params[227],params[228],wires=1)
    qml.U3(params[229],params[230],params[231],wires=2)




    qml.RZ(params[232],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[233],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[234],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[235],wires=[4])
    qml.CNOT(wires=[1,4])
    qml.RZ(params[236],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[237],wires=[4])
    qml.CNOT(wires=[2,4])
    qml.RZ(params[238],wires=[4])
    qml.CNOT(wires=[3,4])
    qml.RZ(params[239],wires=[4])
    qml.CNOT(wires=[1,4])




    qml.U3(params[240],params[241],params[242],wires=1)
    qml.U3(params[243],params[244],params[245],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[246],wires=1)
    qml.RY(params[247],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[248],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[249],params[250],params[251],wires=1)
    qml.U3(params[252],params[253],params[254],wires=2)

    qml.RZ(params[255],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[256],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[257],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[258],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[259],params[260],params[261],wires=1)
    qml.U3(params[262],params[263],params[264],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[265],wires=1)
    qml.RY(params[266],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[267],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[268],params[269],params[270],wires=1)
    qml.U3(params[271],params[272],params[273],wires=2)

    qml.RY(params[274],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[275],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RY(params[276],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RY(params[277],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[278],params[279],params[280],wires=1)
    qml.U3(params[281],params[282],params[283],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[284],wires=1)
    qml.RY(params[285],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[286],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[287],params[288],params[289],wires=1)
    qml.U3(params[290],params[291],params[292],wires=2)

    qml.RZ(params[293],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[294],wires=[3])
    qml.CNOT(wires=[1,3])
    qml.RZ(params[295],wires=[3])
    qml.CNOT(wires=[2,3])
    qml.RZ(params[296],wires=[3])
    qml.CNOT(wires=[1,3])

    qml.U3(params[297],params[298],params[299],wires=1)
    qml.U3(params[300],params[301],params[302],wires=2)
    qml.CNOT(wires=[2,1])
    qml.RZ(params[303],wires=1)
    qml.RY(params[304],wires=2)
    qml.CNOT(wires=[1,2])
    qml.RY(params[305],wires=2)
    qml.CNOT(wires=[2,1])
    qml.U3(params[306],params[307],params[308],wires=1)
    qml.U3(params[309],params[310],params[311],wires=2)





    qml.DepolarizingChannel(1-p,wires=1)
    qml.DepolarizingChannel(1-p,wires=2)
    qml.DepolarizingChannel(1-p,wires=3)
    qml.DepolarizingChannel(1-p,wires=4)



    qml.adjoint(qml.U3(params[309],params[310],params[311],wires=2))
    qml.adjoint(qml.U3(params[306],params[307],params[308],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[305],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[304],wires=2))
    qml.adjoint(qml.RZ(params[303],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[300],params[301],params[302],wires=2))
    qml.adjoint(qml.U3(params[297],params[298],params[299],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[296], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[295], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[294], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[293], wires=3))

    qml.adjoint(qml.U3(params[290],params[291],params[292],wires=2))
    qml.adjoint(qml.U3(params[287],params[288],params[289],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[286],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[285],wires=2))
    qml.adjoint(qml.RZ(params[284],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[281],params[282],params[283],wires=2))
    qml.adjoint(qml.U3(params[278],params[279],params[280],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[277], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[276], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[275], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[274], wires=3))

    qml.adjoint(qml.U3(params[271],params[272],params[273],wires=2))
    qml.adjoint(qml.U3(params[268],params[269],params[270],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[267],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[266],wires=2))
    qml.adjoint(qml.RZ(params[265],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[262],params[263],params[264],wires=2))
    qml.adjoint(qml.U3(params[259],params[260],params[261],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[258], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[257], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[256], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[255], wires=3))

    qml.adjoint(qml.U3(params[252],params[253],params[254],wires=2))
    qml.adjoint(qml.U3(params[249],params[250],params[251],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[248],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[247],wires=2))
    qml.adjoint(qml.RZ(params[246],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[243],params[244],params[245],wires=2))
    qml.adjoint(qml.U3(params[240],params[241],params[242],wires=1))



    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[239], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[238], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[237], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[236], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[235], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[234], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[233], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[232], wires=4))



    qml.adjoint(qml.U3(params[229],params[230],params[231],wires=2))
    qml.adjoint(qml.U3(params[226],params[227],params[228],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[225],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[224],wires=2))
    qml.adjoint(qml.RZ(params[223],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[220],params[221],params[222],wires=2))
    qml.adjoint(qml.U3(params[217],params[218],params[219],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[216], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[215], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[214], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[213], wires=3))

    qml.adjoint(qml.U3(params[210],params[211],params[212],wires=2))
    qml.adjoint(qml.U3(params[207],params[208],params[209],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[206],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[205],wires=2))
    qml.adjoint(qml.RZ(params[204],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[201],params[202],params[203],wires=2))
    qml.adjoint(qml.U3(params[198],params[199],params[200],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[197], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[196], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[195], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[194], wires=3))

    qml.adjoint(qml.U3(params[191],params[192],params[193],wires=2))
    qml.adjoint(qml.U3(params[188],params[189],params[190],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[187],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[186],wires=2))
    qml.adjoint(qml.RZ(params[185],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[182],params[183],params[184],wires=2))
    qml.adjoint(qml.U3(params[179],params[180],params[181],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[178], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[177], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[176], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[175], wires=3))

    qml.adjoint(qml.U3(params[172],params[173],params[174],wires=2))
    qml.adjoint(qml.U3(params[169],params[170],params[171],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[168],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[167],wires=2))
    qml.adjoint(qml.RZ(params[166],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[163],params[164],params[165],wires=2))
    qml.adjoint(qml.U3(params[160],params[161],params[162],wires=1))


    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RY(params[159], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[158], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RY(params[157], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[156], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RY(params[155], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[154], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RY(params[153], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RY(params[152], wires=4))



    qml.adjoint(qml.U3(params[149],params[150],params[151],wires=2))
    qml.adjoint(qml.U3(params[146],params[147],params[148],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[145],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[144],wires=2))
    qml.adjoint(qml.RZ(params[143],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[140],params[141],params[142],wires=2))
    qml.adjoint(qml.U3(params[137],params[138],params[139],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[136], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[135], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[134], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[133], wires=3))

    qml.adjoint(qml.U3(params[130],params[131],params[132],wires=2))
    qml.adjoint(qml.U3(params[127],params[128],params[129],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[126],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[125],wires=2))
    qml.adjoint(qml.RZ(params[124],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[121],params[122],params[123],wires=2))
    qml.adjoint(qml.U3(params[118],params[119],params[120],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[117], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[116], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[115], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[114], wires=3))

    qml.adjoint(qml.U3(params[111],params[112],params[113],wires=2))
    qml.adjoint(qml.U3(params[108],params[109],params[110],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[107],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[106],wires=2))
    qml.adjoint(qml.RZ(params[105],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[102],params[103],params[104],wires=2))
    qml.adjoint(qml.U3(params[99],params[100],params[101],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[98], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[97], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[96], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[95], wires=3))

    qml.adjoint(qml.U3(params[92],params[93],params[94],wires=2))
    qml.adjoint(qml.U3(params[89],params[90],params[91],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[88],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[87],wires=2))
    qml.adjoint(qml.RZ(params[86],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[83],params[84],params[85],wires=2))
    qml.adjoint(qml.U3(params[80],params[81],params[82],wires=1))



    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[79], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[78], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[77], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[76], wires=4))
    qml.CNOT(wires=[1,4])
    qml.adjoint(qml.RZ(params[75], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[74], wires=4))
    qml.CNOT(wires=[2,4])
    qml.adjoint(qml.RZ(params[73], wires=4))
    qml.CNOT(wires=[3,4])
    qml.adjoint(qml.RZ(params[72], wires=4))



    qml.adjoint(qml.U3(params[69],params[70],params[71],wires=2))
    qml.adjoint(qml.U3(params[66],params[67],params[68],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[65],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[64],wires=2))
    qml.adjoint(qml.RZ(params[63],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[60],params[61],params[62],wires=2))
    qml.adjoint(qml.U3(params[57],params[58],params[59],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[56], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[55], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[54], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[53], wires=3))

    qml.adjoint(qml.U3(params[50],params[51],params[52],wires=2))
    qml.adjoint(qml.U3(params[47],params[48],params[49],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[46],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[45],wires=2))
    qml.adjoint(qml.RZ(params[44],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[41],params[42],params[43],wires=2))
    qml.adjoint(qml.U3(params[38],params[39],params[40],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[37], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[36], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RY(params[35], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RY(params[34], wires=3))

    qml.adjoint(qml.U3(params[31],params[32],params[33],wires=2))
    qml.adjoint(qml.U3(params[28],params[29],params[30],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[27],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[26],wires=2))
    qml.adjoint(qml.RZ(params[25],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[22],params[23],params[24],wires=2))
    qml.adjoint(qml.U3(params[19],params[20],params[21],wires=1))

    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[18], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[17], wires=3))
    qml.CNOT(wires=[1,3])
    qml.adjoint(qml.RZ(params[16], wires=3))
    qml.CNOT(wires=[2,3])
    qml.adjoint(qml.RZ(params[15], wires=3))

    qml.adjoint(qml.U3(params[12],params[13],params[14],wires=2))
    qml.adjoint(qml.U3(params[9],params[10],params[11],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.RY(params[8],wires=2))
    qml.CNOT(wires=[1,2])
    qml.adjoint(qml.RY(params[7],wires=2))
    qml.adjoint(qml.RZ(params[6],wires=1))
    qml.CNOT(wires=[2,1])
    qml.adjoint(qml.U3(params[3],params[4],params[5],wires=2))
    qml.adjoint(qml.U3(params[0],params[1],params[2],wires=1))


    qml.QubitUnitary(proj, wires=2)
    qml.QubitUnitary(proj, wires=3)
    qml.QubitUnitary(proj, wires=4)
    return qml.density_matrix(wires=[0, 1])

# %%
def measure_AB(dev, bell_pair, A, B):
    @qml.qnode(dev)
    def circuit(params,p):
        bell_pair(params[:312],p) 
        return qml.expval(qml.Hermitian(A, wires=0) @ qml.Hermitian(B, wires=1))
    return circuit

# Cost function
def cost(params,p):
    # Creating observables with new parameters
    A1 = create_observable(0, 0)
    A2 = create_observable(np.pi/2, 0)
    B1 = create_observable(np.pi/4, 0)
    B2 = create_observable(np.pi/4, np.pi)
    trace=np.trace(bell_pair1(params,p))

    trace=np.trace(bell_pair1(params,p))

    expvals = [measure_AB(dev, bell_pair, A1, B1)(params,p)/trace,
               measure_AB(dev, bell_pair, A1, B2)(params,p)/trace,
               measure_AB(dev, bell_pair, A2, B1)(params,p)/trace,
               measure_AB(dev, bell_pair, A2, B2)(params,p)/trace]
    # trace=1 #np.trace(bell_pair1(params,p))
    return -np.real((np.sum(expvals[:3]) - expvals[3]))

# %%
p_val = linspace(0.25,1,0.5)
CHSH = []
par = []
Prob_SUCESS = []


adam_opt = qml.AdamOptimizer(0.1)
adam_steps = 1000

for p in p_val:
    params = np.array(np.random.uniform(-np.pi, np.pi,312), requires_grad=True)
    

    for i in range(adam_steps):
        params, ccost = adam_opt.step_and_cost(lambda v: cost(v, p), params)
        print(f"Step {i + 1}/{adam_steps}, Cost: {ccost}")

    PS = np.trace(bell_pair1(params, p))

    CHSH.append(ccost)
    par.append(params)
    Prob_SUCESS.append(PS)

print("CHSH:", CHSH)
print("Params:", par)
print("Prob_SUCESS:", Prob_SUCESS)
# Out:
# Adam Step 1/50, Cost: -2.7646101364962705
# Adam Step 2/50, Cost: -2.7073159929547956
# Adam Step 3/50, Cost: -2.72972072995066
# Adam Step 4/50, Cost: -2.764072530144059
# Adam Step 5/50, Cost: -2.7746616531337596
# Adam Step 6/50, Cost: -2.7722544758752905
# Adam Step 7/50, Cost: -2.7766822845537287
# Adam Step 8/50, Cost: -2.7875024606868126
# Adam Step 9/50, Cost: -2.789223050285287
# Adam Step 10/50, Cost: -2.7969723641908844
# Adam Step 11/50, Cost: -2.7937811233563306
# Adam Step 12/50, Cost: -2.8010443645653273
# Adam Step 13/50, Cost: -2.804646555233953
# Adam Step 14/50, Cost: -2.808326325807558
# Adam Step 15/50, Cost: -2.8100474422964696
# Adam Step 16/50, Cost: -2.8121220845729424
# Adam Step 17/50, Cost: -2.811672502604287
# Adam Step 18/50, Cost: -2.812379056908762
# Adam Step 19/50, Cost: -2.8133092430738578
# Adam Step 20/50, Cost: -2.815086490088436
# Adam Step 21/50, Cost: -2.815544741817295
# Adam Step 22/50, Cost: -2.81647272607185
# ...

# %%
# [tensor(1.99699575, requires_grad=True), tensor(2.00598162, requires_grad=True), tensor(2.02460369, requires_grad=True), tensor(2.0581806, requires_grad=True), tensor(2.11178293, requires_grad=True), tensor(2.18644232, requires_grad=True), tensor(2.28227571, requires_grad=True), tensor(2.39369046, requires_grad=True), tensor(2.51868766, requires_grad=True), tensor(2.65319462, requires_grad=True), tensor(2.79724831, requires_grad=True)]

# %%
ff2num=[1.2570746207745944,1.4524211060312373,1.6347157870755842,1.893706357626605,2.1213153933900877,2.3141617280689117,2.4725297796839607,2.5990931082738653,2.697764062802358,2.7728310142540216,2.8284271247461295]
fp2num=[0.33333409170039996,0.3699969360359927,.37628363826743525,0.3969638513840199,0.448001387896786,0.5092609245981687,0.581630147669126,0.6660004418135237,0.7632596011147079,0.8742965722235594,1.00000000000000]
ff3num=[1.3309393412744939,1.465062563767017,1.7824572925192355,2.092200842441211,2.3381214650484865,2.5217971635060175,2.6539940820474843,2.7409302374922477,2.7899045684995905,2.8208220064088847,2.8284271247461295]
fp3num=[0.20986631753634732,0.24798992287670318,0.2595406072977397,0.26678305549245294,0.2960527204256679,0.3600390994055117,0.4401551702555653,0.5409932367974899,0.6653093367551646,0.8169513809108573,1.00000000000]
